# %% [markdown]
# # 1. Data Preprocessing

# %%
import pandas as pd
import numpy as np

# %%
raw_total = pd.read_excel('./files/1_crawling_raw.xlsx')
raw_total.head()
# Out:
#                                              content        date   like  \
# 0  더 늦기전에 제주도로 떠나쟈😍.#제주핫플레이스 간단히 1탄 모아봄!#제주여행 요 필...  2018-12-07  1,402
# 1  12월에 제주도를 가야하는이유🍊.#제주핫플 모음 끝판왕😍이거 하나면 겨울 #제주여행...  2018-12-03    368
# 2  11월 놓치지 말아야 할 제주 관광.가을바람이 최고조에 이르는 11월추운 겨울을 앞...  2018-11-02    166
# 3  국민학교세대#제주관광#제주살이#제주이주민#아라동주민#삼남매집 #새해첫날#드라이브#명...  2019-01-01     28
# 4  #제주관광 #제주 #돔나이트 #스트레스 #풀자 #춤추며 #땀날려 #가끔은괜찮아 #인...  2019-01-01     12
#
#     place                                               tags
# 0     NaN  ['#제주핫플레이스', '#제주여행', '#제주여행', '#제주도여행', '#제주가...
# 1     NaN  ['#제주핫플', '#제주여행', '#제주', '#제주도', '#제주도맛집', '#...
# 2     NaN  ['#honestin', '#어니스틴', '#제주여행', '#제주', '#제주도',...
# 3  명월국민학교  ['#제주관광', '#제주살이', '#제주이주민', '#아라동주민', '#삼남매집'...
# 4     NaN  ['#제주관광', '#제주', '#돔나이트', '#스트레스', '#풀자', '#춤추...

# %%
location_counts = raw_total.place.value_counts()
location_counts_df = pd.DataFrame(location_counts)
location_counts_df.head()
#location_counts_df.to_excel('./files/3_location_counts.xlsx', index=True)
# Out:
#                       place
# Jeju                    241
# Jeju-do                 172
# Jungle Book by Alice    101
# Seogwipo                 65
# 제주도 크리스마스 박물관            59

# %%
locations = list(location_counts_df.index)
locations
# Out:
# ['Jeju',
#  'Jeju-do',
#  'Jungle Book by Alice',
#  'Seogwipo',
#  '제주도 크리스마스 박물관',
#  '제주에인감귤밭',
#  'Jeju Island',
#  '성산일출봉 城山日出峰  Seongsan Ilchulbong',
#  '폼포코식당_pompokokitchen',
#  '1100고지',
#  'Nimome',
#  '월정리해변',
#  '석부작박물관',
#  '제주도 애월읍',
#  '알뜨르 비행장',
#  '카멜리아 힐',
#  '제주레포츠랜드',
#  '밥깡패',
#  '고집돌우럭중문점',
#  '제주 함덕 서우봉 해변',
#  '제주고궁한복카페 jeju gogung hanbok studio',
#  '제주신화월드 Jeju Shinhwa World',
#  '제주도 서귀포 중문관광단지 濟州島西歸浦中文觀光團地',
#  '할로비치',
#  '위미동백나무군락지',
#  '협재해변 Beach',
#  'Woljeongri Beach',
#  '연동 바오젠 거리',
#  '새별오름',
#  '고래배꼽',
#  '용머리해안',
#  '용눈이오름',
#  '제주빅볼랜드',
#  '김녕미로공원 Jeju Kimnyoung Maze Park',
#  '사려니숲길',
#  '캔디원',
#  '하이엔드 제주',
#  '마마뜰',
#  'Jeju Aewol',
#  '서귀포 느영나영 게스트하우스',
#  '한라산',
#  '위미2리 동백군락지',
#  '위미동백나무군락',
#  'Jeju Island 제주특별자치도 济州道',
#  '제주커피박물관 Baum',
#  '휴애리 자연생활공원',
#  '삼무공원',
#  '서우봉',
#  '한라산 (漢拏山, Hallasan)',
#  '제주해남',
#  '광치기해변',
#  '제주어린왕자게스트하우스',
#  '월정리카페콧수염',
#  '옹포별장가든',
#  '성이시돌목장',
#  '제주 송악산',
#  '카페한라산',
#  '산굼부리',
#  '카페브리프',
# ...

# %% [markdown]
# # 2. API request

# %%
import requests

# %%
# API
searching = '합정 스타벅스'
url ='http://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)

headers ={
    'Authorization' : '***'
}

places = requests.get(url, headers = headers).json()['documents']

# %%
places[0]
# Out:
# {'address_name': '서울 마포구 서교동 395-166',
#  'category_group_code': 'CE7',
#  'category_group_name': '카페',
#  'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#  'distance': '',
#  'id': '26572121',
#  'phone': '1522-3232',
#  'place_name': '스타벅스 서교점',
#  'place_url': 'http://place.map.kakao.com/26572121',
#  'road_address_name': '서울 마포구 양화로 78',
#  'x': '126.916980454434',
#  'y': '37.5514601750423'}

# %%
# 함수화
def find_places(searching):
    url ='http://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)

    headers ={
        'Authorization' : 'KakaoAK 1597c56a87206f611333102f99f1d947'
    }

    places = requests.get(url, headers = headers).json()['documents']
    place = places[0]
    
    name = place['place_name']
    x = place['x'] # 경도
    y = place['y'] # 위도
    data = [name, x, y, searching]
    
    return data

# %%
find_places('합정 스타벅스')
# Out:
# ['스타벅스 서교점', '126.916980454434', '37.5514601750423', '합정 스타벅스']

# %%
# 인스타그램 위치명에 대한 정보 검색
from tqdm.notebook import tqdm # loading bar
import time

location_inform = []

for location in tqdm(locations[:20]):
    try:
        data = find_places(location)
        location_inform.append(data)
        time.sleep(1)
    except:
        pass
    
location_inform
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# [['Jeju in aA', '126.83650369902168', '33.53833652360498', 'Jeju'],
#  ['서귀포잠수함', '126.558616052674', '33.2393033784206', 'Seogwipo'],
#  ['바이나흐튼 크리스마스박물관', '126.32785786016811', '33.2915720831759', '제주도 크리스마스 박물관'],
#  ['제주에인감귤밭', '126.5390139270361', '33.25656069063887', '제주에인감귤밭'],
#  ['제주도', '126.54587355630036', '33.379777816446165', 'Jeju Island'],
#  ['한라산1100고지', '126.462219691112', '33.3580781709788', '1100고지'],
#  ['월정리해수욕장', '126.795805057888', '33.556469394054', '월정리해변'],
#  ['석부작박물관', '126.536501983154', '33.2504031491774', '석부작박물관'],
#  ['올레길 16코스(고내-광령 올레)', '126.38979561557086', '33.46649759191228', '제주도 애월읍'],
#  ['알뜨르비행장', '126.271527320164', '33.2047161778831', '알뜨르 비행장'],
#  ['카멜리아힐', '126.370009467525', '33.2896344311608', '카멜리아 힐'],
#  ['제주레포츠랜드', '126.6387551242765', '33.48206819907232', '제주레포츠랜드'],
#  ['유진푸드', '127.387893413315', '36.3562604784963', '밥깡패'],
# ...

# %%
location_inform_df = pd.DataFrame(location_inform)
location_inform_df.columns = ['name_official', 'lon', 'lat', 'name']
#location_inform-_df.to_excel('files/3_location_inform_class.xlsx')

location_inform_df.head()
# Out:
#     name_official                 lon                 lat           name
# 0      Jeju in aA  126.83650369902168   33.53833652360498           Jeju
# 1          서귀포잠수함    126.558616052674    33.2393033784206       Seogwipo
# 2  바이나흐튼 크리스마스박물관  126.32785786016811    33.2915720831759  제주도 크리스마스 박물관
# 3         제주에인감귤밭   126.5390139270361   33.25656069063887        제주에인감귤밭
# 4             제주도  126.54587355630036  33.379777816446165    Jeju Island

# %% [markdown]
# # 3. 인스타 정보량 매칭

# %%
location_counts_df = pd.read_excel('./files/3_location_counts.xlsx', index_col=0)
location_inform_df = pd.read_excel('./files/3_locations.xlsx')

# %%
location_counts_df.head()
# Out:
#                       place
# Jeju                    271
# Jeju-do                 179
# Jungle Book by Alice    108
# Seogwipo                 66
# 제주도 크리스마스 박물관            59

# %%
location_inform_df.head()
# Out:
#     name_official          경도         위도         인스타위치명
# 0      Jeju in aA  126.836504  33.538337           Jeju
# 1          서귀포잠수함  126.558616  33.239303       Seogwipo
# 2  바이나흐튼 크리스마스박물관  126.327864  33.291569  제주도 크리스마스 박물관
# 3            할로비치  127.020826  37.518211           할로비치
# 4         제주에인감귤밭  126.539410  33.256610        제주에인감귤밭

# %%
location_data = pd.merge(left=location_inform_df,
                        right = location_counts_df,
                        how='inner',
                        left_on='name_official',
                        right_index=True)

location_data.head()
# Out:
#     name_official          경도         위도       인스타위치명  place
# 1          서귀포잠수함  126.558616  33.239303     Seogwipo      1
# 308        서귀포잠수함  126.558616  33.239303       서귀포잠수함      1
# 3            할로비치  127.020826  37.518211         할로비치     51
# 4         제주에인감귤밭  126.539410  33.256610      제주에인감귤밭     48
# 5             제주도  126.545876  33.379777  Jeju Island      4

# %%
# 중복데이터 검색
location_data['name_official'].value_counts()
# Out:
# 오설록티뮤지엄           3
# 서귀포잠수함            2
# 천지연폭포             2
# 빌라드아토             2
# 비자림               2
#                  ..
# 투썸플레이스 제주애월한담점    1
# 하늘고래              1
# 문쏘                1
# 성산일출봉             1
# 신풍목장              1
# Name: name_official, Length: 416, dtype: int64

# %%
# 중복데이터 합산
location_data = location_data.pivot_table(values='place', index=['name_official','위도','경도'],
                         aggfunc='sum')
location_data.head()
# Out:
#                                     place
# name_official 위도        경도
# 73st          33.456989 126.455109      1
# 가드망제          33.500991 126.532954      1
# 가배            33.231541 126.505570      1
# 가시식당          33.353060 126.771438      2
# 가시아방국수        33.438605 126.918072      2

# %% [markdown]
# # 4. Mapping

# %%
# js의 leaflet을 python에서 사용할 수 있도록 연동해주는 라이브러리.
import folium

# test
lat = 37.394946
lon = 127.1111
m = folium.Map(location=[lat, lon], width= 700, hight= 300,
              zoom_start=15)

myicon = folium.Icon(color='red', icon_color='yellow', icon='info-sign',
                    prefix = 'glyphicon')
folium.Marker(location=[lat,lon], popup='판교역', tooltip='판교역 입구',
             icon=myicon).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# FontAwesome : Icon FA 무료사용가능. prefix fa 설정 필요.
# popup : 소스코드, 링크 등 설정 가능
# CircleMarker :
m = folium.Map(location=[lat, lon], width= 700, hight= 300,
              zoom_start=15)

myicon = folium.Icon(color='red', icon_color='white', icon='wifi',
                    prefix = 'fa')
folium.Marker(location=[lat,lon], popup='<iframe width="300" height="150" src="https://www.youtube.com/embed/R7L2QEm-BUY" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>',
              tooltip='Rainyday', icon=myicon).add_to(m)

folium.CircleMarker(location=[lat,lon], color='tomato', radius=50,
                   tooltip='활동반경').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# Youtube
# Marker Circle
location_data.reset_index(inplace=True)

Mt_Hanla = [33.3625, 126.533694]
map_jeju = folium.Map(location= Mt_Hanla, zoom_start = 11)

# default :openstreetmap
folium.TileLayer().add_to(map_jeju)

for i in range(len(location_data)):
    name = location_data['name_official'][i]
    count = location_data['place'][i]
    size = int(count*2)
    lat = location_data['위도'][i]
    lon = location_data['경도'][i]
    
    folium.CircleMarker(location=[lat,lon], radius=size, color='tomato',
                       popup=name).add_to(map_jeju)
    
map_jeju
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# map_jeju.save('./files/3_jeju.html')

# %%
# Marker Cluster
from folium.plugins import MarkerCluster

locations = []
names = []

for i in range(len(location_data)):
    data = location_data.iloc[i]
    locations.append([data['위도'], data['경도']])
    names.append(data['name_official'])
    
Mt_Hanla = [33.3625, 126.533694]
map_jeju2 = folium.Map(location= Mt_Hanla, zoom_start = 11)

tiles = ['stamenwatercolor', 'cartodbpositron', 'openstreetmap', 'stamenterrain']

for tile in tiles:
    folium.TileLayer(tile).add_to(map_jeju2)
    
marker_cluster = MarkerCluster(locations = locations, popups = names,
                              name = 'Jeju', overlay=True, control=True).add_to(map_jeju2)

folium.LayerControl().add_to(map_jeju2)
map_jeju2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
