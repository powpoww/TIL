# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
cat= pd.read_csv('../data/item_splitcat_kor.csv')
sales = pd.read_csv('../data/raw/sales_train.csv')
item = pd.read_csv('../data/raw/items.csv')

# %%
cat.head()
# Out:
#   item_category_name  item_category_id category1  category2  category1_id  \
# 0     PC - 헤드셋 / 헤드폰                 0        PC  헤드셋 / 헤드폰             0
# 1        액세서리 - PS2.                 1      액세서리       PS2.            10
# 2        액세서리 - PS3.                 2      액세서리       PS3.            10
# 3        액세서리 - PS4.                 3      액세서리       PS4.            10
# 4        액세서리 - PSP.                 4      액세서리       PSP.            10
#
#    category2_id
# 0            60
# 1             6
# 2             7
# 3             8
# 4            10

# %%
item.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
val_list = ['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
       'item_cnt_day', 'item_category_id', 'item_category_name', 'category1_id', 'category2_id']

_ = pd.merge(item, cat, on= 'item_category_id')
sal_merge = pd.merge(sales, _, on='item_id')[val_list]

sal_merge
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154       999.0
# 1        23.01.2013               0       24    22154       999.0
# 2        20.01.2013               0       27    22154       999.0
# 3        02.01.2013               0       25    22154       999.0
# 4        03.01.2013               0       25    22154       999.0
# ...             ...             ...      ...      ...         ...
# 2935844  17.10.2015              33       25     8428       249.0
# 2935845  01.10.2015              33       25     7903     12198.0
# 2935846  29.10.2015              33       25     7610      2890.0
# 2935847  22.10.2015              33       25     7635      2100.0
# 2935848  01.10.2015              33       25     7640      4040.0
#
#          item_cnt_day  item_category_id item_category_name  category1_id  \
# 0                 1.0                37         필름 - 블루 레이            20
# ...

# %%
sns.heatmap(sal_merge.corr())
# Out:
# <AxesSubplot:>
